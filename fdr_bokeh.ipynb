# %% [markdown]
# ##### bokeh 최신버젼은 vscode에서 오류발생
# ```
# pip install bokeh==2.4.1
# ```

# %%
import bokeh
import FinanceDataReader as fdr
bokeh.__version__  #  '2.4.1' 
                   
df = fdr.DataReader('079160', '2021-11')  # CJ CGV
df.head(10)
# df['Close'].plot()
fdr.chart.plot(df)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="899156a8-e5ef-4e47-9837-e4815f4db2ea" data-root-id="1163"></div>

# %%
import FinanceDataReader as fdr
fdr.__version__   # 0.9.50
# Out:
# '0.9.50'
