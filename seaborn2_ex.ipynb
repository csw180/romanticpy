# %% [markdown]
# [https://seaborn.pydata.org/tutorial/relational.html](https://seaborn.pydata.org/tutorial/relational.html)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='darkgrid')

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip', hue='smoker', style='time')
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip', size='size', sizes=(15,200))
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(data=tips, x='total_bill', y='tip', hue='smoker', style='time')

# %%
sns.relplot(data=tips, x='total_bill', y='tip', size='size', sizes=(15,200))

# %%
# relplot 은 sdcatterplot 와 다르게 col='smoker',row='time' 와 같이 서브플롯을 그리는 기능있음
sns.relplot(data=tips, x='total_bill', y='tip', col='smoker',row='time', hue='smoker',size='size', sizes=(15,200))
